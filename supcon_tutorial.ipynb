# %%
import models
from contrastive import ContrastiveModel, ContrastiveModel_ori
import time
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau
from matplotlib import pyplot as pt
import matplotlib.colors as mcolors
from sklearn.manifold import TSNE
from sklearn.preprocessing import MinMaxScaler

# 1. 定義訓練資料時間段
source_time_periods = [
    ('2025-04-11 09:14:01', '2025-04-11 09:34:00', 1),
    ('2025-04-11 09:46:01', '2025-04-11 10:06:00', 1),
    ('2025-04-11 10:29:01', '2025-04-11 10:49:00', 2),
    ('2025-04-11 11:01:01', '2025-04-11 11:21:00', 2),
    ('2025-04-11 11:33:01', '2025-04-11 11:53:00', 2),
    ('2025-04-11 12:05:01', '2025-04-11 13:05:00', 0),
    ('2025-04-11 13:45:01', '2025-04-11 14:05:00', 7),
    ('2025-04-11 14:19:01', '2025-04-11 14:39:00', 7),
    ('2025-04-11 14:52:01', '2025-04-11 15:12:00', 7),
    ('2025-04-11 15:46:01', '2025-04-11 16:06:00', 0),
    ('2025-04-14 09:00:01', '2025-04-14 09:40:00', 0),
    ('2025-04-14 10:49:01', '2025-04-14 11:30:00', 8),
    ('2025-04-14 13:25:01', '2025-04-14 14:05:00', 3), 
    ('2025-04-14 14:50:01', '2025-04-14 15:30:00', 3),
    ('2025-12-23 10:23:01', '2025-12-23 11:03:00', 0),
    ('2025-12-23 13:19:01', '2025-12-23 13:40:00', 1),
    ('2025-12-23 14:03:01', '2025-12-23 14:23:00', 1),
    ('2025-12-23 15:00:01', '2025-12-23 15:40:00', 3),
    ('2026-01-01 00:00:01', '2026-01-01 01:00:00', 4),
    ('2026-01-01 01:30:01', '2026-01-01 02:30:00', 4),
    ('2026-01-01 03:00:01', '2026-01-01 04:00:00', 4),
    ('2026-01-01 05:00:01', '2026-01-01 06:00:00', 5),
    ('2026-01-01 06:30:01', '2026-01-01 07:30:00', 5),
    ('2026-01-01 08:00:01', '2026-01-01 09:00:00', 5),
    ('2026-01-01 10:00:01', '2026-01-01 11:00:00', 6),
    ('2026-01-01 11:30:01', '2026-01-01 12:30:00', 6), 
    ('2026-01-01 13:00:01', '2026-01-01 14:00:00', 6),
    ('2026-01-01 15:00:01', '2026-01-01 15:40:00', 9),
    ('2026-01-01 15:56:01', '2026-01-01 16:36:00', 9),
    ('2026-01-01 16:52:01', '2026-01-01 17:32:00', 9)
]

# 2. 定義測試資料時間段
test_time_periods = [
    ('2025-04-11 09:34:01', '2025-04-11 09:44:00', 1, '冷凝盤管阻塞20%'),
    ('2025-04-11 10:06:01', '2025-04-11 10:16:00', 1, '冷凝盤管阻塞30%'),
    ('2025-04-11 10:49:01', '2025-04-11 10:59:00', 2, '蒸發盤管阻塞10%'),
    ('2025-04-11 11:21:01', '2025-04-11 11:31:00', 2, '蒸發盤管阻塞20%'),
    ('2025-04-11 11:53:01', '2025-04-11 12:03:00', 2, '蒸發盤管阻塞23%'),
    ('2025-04-11 13:05:01', '2025-04-11 13:35:00', 0, '正常資料常溫34度'),
    ('2025-04-11 14:05:01', '2025-04-11 14:15:00', 7, '蒸發風扇電流90%'),
    ('2025-04-11 14:39:01', '2025-04-11 14:49:00', 7, '蒸發風扇電流80%'),
    ('2025-04-11 15:12:01', '2025-04-11 15:22:00', 7, '蒸發風扇電流70%'),
    ('2025-04-11 16:06:01', '2025-04-11 16:16:00', 0, '正常資料高溫42.7度'),
    ('2025-04-14 09:40:01', '2025-04-14 10:00:00', 0, '正常資料低溫24度'),
    ('2025-04-14 11:30:01', '2025-04-14 11:45:00', 8, '加熱器運轉'),
    ('2025-04-14 14:05:01', '2025-04-14 14:25:00', 3, '冷媒洩漏10%'),
    ('2025-04-14 15:30:01', '2025-04-14 15:50:00', 3, '冷媒洩漏20%'),
    ('2025-12-23 11:03:01', '2025-12-23 11:23:00', 0, '正常資料低溫27度'),
    ('2025-12-23 13:40:01', '2025-12-23 13:57:00', 1, '輕度冷凝盤管阻塞'),
    ('2025-12-23 14:23:01', '2025-12-23 14:33:00', 1, '重度冷凝盤管阻塞'),
    ('2025-12-23 15:40:01', '2025-12-23 16:00:00', 3, '冷媒洩漏30%'),
    ('2026-01-01 01:00:01', '2026-01-01 01:30:00', 4, '壓縮機故障10%'),
    ('2026-01-01 02:30:01', '2026-01-01 03:00:00', 4, '壓縮機故障20%'),
    ('2026-01-01 04:00:01', '2026-01-01 04:30:00', 4, '壓縮機故障30%'),
    ('2026-01-01 06:00:01', '2026-01-01 06:30:00', 5, '冷凝風扇電流上升10%'),
    ('2026-01-01 07:30:01', '2026-01-01 08:00:00', 5, '冷凝風扇電流上升20%'),
    ('2026-01-01 09:00:01', '2026-01-01 09:30:00', 5, '冷凝風扇電流上升30%'),
    ('2026-01-01 11:00:01', '2026-01-01 11:30:00', 6, '蒸發風扇電流上升10%'),
    ('2026-01-01 12:30:01', '2026-01-01 13:00:00', 6, '蒸發風扇電流上升20%'),
    ('2026-01-01 14:00:01', '2026-01-01 14:30:00', 6, '蒸發風扇電流上升30%'),
    ('2026-01-01 15:40:01', '2026-01-01 15:56:00', 9, '加熱器故障10%'),
    ('2026-01-01 16:36:01', '2026-01-01 16:52:00', 9, '加熱器故障20%'),
    ('2026-01-01 17:32:01', '2026-01-01 17:48:00', 9, '加熱器故障30%')
]

# 3. 設定特徵
target_features = [
    'hp_comp_1','lp_comp_1','comp_current_1','cond_current_1','fan_current_1',
    'return_air_temp','outdoor_temp','lp_plate_temp_1','superheat_1','h_suc_1',
    'heater_temp'
]

# %% [markdown]
# ## Loss functions and some useful tools:
#
# - modified supcon loss
#
# - original supcon loss
#
# - ucr datasets reader
#
# - data augmentation for supcon learning
#
# - create augmentation pairs for SimCLR
#
# - data validation

# %%
def supcon_loss(y_true, y_pred):
    temp = 1
    t = tf.cast(temp, tf.float32)
    y_true = tf.convert_to_tensor(y_true)
    y_pred = tf.convert_to_tensor(y_pred)
    
    mask = tf.math.equal(y_true, tf.transpose(y_true))
    mask = tf.cast(mask, tf.float32)
    batch_size = tf.shape(mask)[0]
    remove = tf.eye(batch_size)
    mask = mask-remove
    num_pos = tf.reduce_sum(mask, axis=1)
    logits = tf.matmul(y_pred, y_pred, transpose_b=True)
    logits = logits/t
    logits = (logits - tf.reduce_max(tf.stop_gradient(logits), axis=1, keepdims=True))
    exp_logits = tf.exp(logits)
    d_mask = tf.ones((batch_size, batch_size))
    d_mask = d_mask-remove
    denominator = exp_logits*d_mask
    denominator = tf.reduce_sum(denominator, axis=1, keepdims=True)
    log_probs = (logits - tf.math.log(denominator))*mask
    log_probs = tf.reduce_sum(log_probs, axis=1)
    log_probs = tf.math.divide_no_nan(log_probs, num_pos)
    
    loss = -log_probs
    loss = loss*t
    return loss

def supcon_loss_ori(y_true, y_pred):
    temp = 1
    t = tf.cast(temp, tf.float32)
    y_true = tf.convert_to_tensor(y_true)
    y_pred = tf.convert_to_tensor(y_pred)
    
    mask = tf.math.equal(y_true, tf.transpose(y_true))
    mask = tf.cast(mask, tf.float32)
    batch_size = tf.shape(y_pred)[0]
    num_views = tf.shape(y_pred)[1]
    mask = tf.tile(mask, [num_views, num_views])
    logits_mask = tf.ones_like(mask) - tf.eye(tf.shape(mask)[0])
    mask = mask*logits_mask
    
    y_pred = tf.reshape(tf.transpose(y_pred, perm=[1,0,2]), [batch_size*num_views, -1])
    
    num_pos = tf.reduce_sum(mask, axis=1)
    logits = tf.matmul(y_pred, y_pred, transpose_b=True)
    logits = logits/t
    logits = (logits - tf.reduce_max(tf.stop_gradient(logits), axis=1, keepdims=True))
    exp_logits = tf.exp(logits)

    denominator = exp_logits*logits_mask
    denominator = tf.reduce_sum(denominator, axis=1, keepdims=True)
    log_probs = (logits - tf.math.log(denominator))*mask
    log_probs = tf.reduce_sum(log_probs, axis=1)
    log_probs = tf.math.divide_no_nan(log_probs, num_pos)
    
    loss = -log_probs
    loss = loss*t
    loss = tf.reshape(loss, [num_views, batch_size])
    return tf.reduce_mean(loss, axis=0)

def readucr(filename):
    data = np.loadtxt(filename, delimiter="\t")
    y = data[:, 0]
    x = data[:, 1:]
    return x, y.astype(float)

def create_windows(data, label, window_size, step_size):
    """將連續時間序列切割為固定長度的滑動視窗"""
    windows = []
    labels = []
    # 確保資料為 numpy array
    data_values = data.values if isinstance(data, pd.DataFrame) else data
    for i in range(0, len(data_values) - window_size + 1, step_size):
        windows.append(data_values[i:i + window_size])
        labels.append(label)
    return np.array(windows), np.array(labels)

def prepare_dataset(df, periods, features, window_size, step_size):
    """根據時間段過濾資料並生成特徵與標籤陣列"""
    x_list, y_list = [], []
    for item in periods:
        start = item[0]
        end = item[1]
        label = item[2]
        
        # 篩選特定時間段資料
        mask = (df.index >= start) & (df.index <= end)
        segment = df.loc[mask, features]
        
        # 確認該區間長度是否足夠產生至少一個 window
        if len(segment) >= window_size:
            x_win, y_win = create_windows(segment, label, window_size, step_size)
            x_list.append(x_win)
            y_list.append(y_win)
            
    if len(x_list) > 0:
        return np.vstack(x_list), np.concatenate(y_list)
    else:
        return np.array([]), np.array([])

def window_warp(x, window_ratio=0.1, scales=[0.5, 2.]):
    # https://halshs.archives-ouvertes.fr/halshs-01357973/document
    warp_scales = np.random.choice(scales, x.shape[0])
    warp_size = np.ceil(window_ratio*x.shape[1]).astype(int)
    window_steps = np.arange(warp_size)
        
    window_starts = np.random.randint(low=1, high=x.shape[1]-warp_size-1, size=(x.shape[0])).astype(int)
    window_ends = (window_starts + warp_size).astype(int)
            
    ret = np.zeros_like(x)
    for i, pat in enumerate(x):
        for dim in range(x.shape[2]):
            start_seg = pat[:window_starts[i],dim]
            window_seg = np.interp(
                np.linspace(0, warp_size-1, num=int(warp_size*warp_scales[i])), 
                window_steps, 
                pat[window_starts[i]:window_ends[i],dim]
            )
            end_seg = pat[window_ends[i]:,dim]
            warped = np.concatenate((start_seg, window_seg, end_seg))                
            ret[i,:,dim] = np.interp(np.arange(x.shape[1]), np.linspace(0, x.shape[1]-1., num=warped.size), warped).T
    return ret

def jitter(x, sigma=0.05):
    return x + np.random.normal(0, sigma, size=(x.shape[0], x.shape[1]))

def scale(x, sigma=0.1):
    factor = np.random.normal(loc=1., scale=sigma, size=(x.shape[0], x.shape[2]))
    return np.multiply(x, factor[:,np.newaxis,:])


def permute(x, seg=2):
    if x.shape[1]%seg != 0:
        nb, n, t =x.shape[0], seg, int(x.shape[1]/seg)+1
        x_per = x[:, :int((seg-1)*t)]
        x_tail = x[:, int((seg-1)*t):]
        x_per = x_per.reshape(nb, n-1, t)
        idx = np.random.permutation(n)
        x_hat = x_per[:, idx[0], :] if idx[0] !=seg-1 else x_tail
        for i in idx[1:]:
            x_add = x_per[:, i, :] if i !=seg-1 else x_tail
            x_hat = np.concatenate((x_hat, x_add), axis=1)
        return x_hat.reshape(nb, x.shape[1])
    
    nb, n, t =x.shape[0], seg, int(x.shape[1]/seg)
    x_hat = x.reshape(nb, n, t)
    idx = np.random.permutation(n)
    x_hat = x_hat[:, idx, :]
    return x_hat.reshape(nb, int(n*t))

def augmentation(x, y, augs=None):
    idx = np.random.permutation(len(x))
    y = y[idx]
    num_aug = len(augs)
    
    if not augs:
        return np.expand_dims(x[idx], axis=-1), np.expand_dims(y[idx], axis=-1)
    
    if len(y.shape) <2:
        y = np.expand_dims(y, axis=-1)
        
    non = x
    jit = jitter(x)
    inv = x[:, ::-1]
    warp = window_warp(np.expand_dims(x, axis=-1))
    warp = np.squeeze(warp) + np.random.normal(0, 0.02, x.shape[1])
    scl = np.squeeze(scale(np.expand_dims(x, axis=-1)))
    pem = permute(x, 3)
    
    new_x = np.array([])
    new_y = np.array([])
    for func in augs:
        aug = locals()[func]
        aug = aug[idx]
        if len(new_x) == 0:
            new_x = aug
            new_y = y
        else:
            new_x = np.concatenate((new_x, aug), axis=-1)
            new_y = np.concatenate((new_y, y), axis=-1)
            
    n, d = new_x.shape
    new_x = np.reshape(new_x, [int(n)*num_aug, int(d/num_aug), 1])
    n, d = new_y.shape
    new_y = np.reshape(new_y, [int(n)*num_aug, int(d/num_aug)])
    return new_x, new_y

def create_pairs(x, y):
    new_x = []
    label = []
    c_label = []
    l = len(x[0])
    for i in range(len(x)):
        ts = x[i]
        ws = ts + np.random.normal(0, 0.03, x.shape[1])
        new_x += [ts]
        label += [i]
        c_label += [y[i]]
        new_x += [ws]
        label += [i]
        c_label += [y[i]]

    return np.array(new_x), np.array(label), np.array(c_label)

def valid(x):
    msk = np.isnan(x)
    x[msk] = np.interp(np.flatnonzero(msk), np.flatnonzero(~msk), x[~msk])
    return x

# %% [markdown]
# ## Load dataset and preprocessing

# %%
# 1. 讀取您的原始資料並將時間設為 Index
# 假設您的資料集時間欄位名稱為 'timestamp'
df = pd.read_csv('cab_data_final_train.csv')
df['timestamp'] = pd.to_datetime(df['datetime'])
df = df.set_index('timestamp')

# 2. 設定視窗大小與滑動步長 (可根據取樣頻率微調)
WINDOW_SIZE = 60  
STEP_SIZE = 1    

# 3. 生成訓練與測試集的三維陣列 (樣本數, Window Size, 特徵數)
x_train_raw, y_train = prepare_dataset(df, source_time_periods, target_features, WINDOW_SIZE, STEP_SIZE)
x_test_raw, y_test = prepare_dataset(df, test_time_periods, target_features, WINDOW_SIZE, STEP_SIZE)

# 4. 資料正規化 (MinMaxScaler)
# 由於 scaler 只能處理二維資料，先將資料展平 (Flatten)，正規化後再轉回三維
num_train_samples, seq_len, num_features = x_train_raw.shape
x_train_flat = x_train_raw.reshape(-1, num_features)

num_test_samples = x_test_raw.shape[0]
x_test_flat = x_test_raw.reshape(-1, num_features)

scaler = MinMaxScaler()
x_train_scaled = scaler.fit_transform(x_train_flat)
x_test_scaled = scaler.transform(x_test_flat)

# 轉回 (樣本數, 時間步長, 特徵數) 結構
x_train = x_train_scaled.reshape(num_train_samples, seq_len, num_features)
x_test = x_test_scaled.reshape(num_test_samples, seq_len, num_features)

# 確認共有幾個類別 (0~9 共 10 類)
n_class = len(np.unique(y_train))
print(f"訓練集維度: {x_train.shape}, 測試集維度: {x_test.shape}, 總類別數: {n_class}")

# %%
'''
    -For special cases
'''
# a, b = np.unique(y_train)
# y_train[y_train==a]=0
# y_train[y_train==b]=1

# y_test[y_test==a] = 0
# y_test[y_test==b] = 1

# %%
pt.plot(x_train[0])

# %%
if np.any(np.isnan(x_train)):
    x_train = valid(x_train)
    x_test = valid(x_test)
    print('data sets validated.')
else:
    print('valid data')
# Out:
# valid data

# %%
n_class = len(np.unique(y_test))

# %%
y_train -= np.unique(y_train)[0]
y_test -= np.unique(y_test)[0]

# %%
augs = ['pem', 'non']                                #augs = 'non', 'jit', 'pem', 'warp' or 'scl'
x_train, y_train = augmentation(x_train, y_train, augs)
num_views = len(augs)

# %%
'''
    -SimCLR mode
    -Each pair is a class of its own
    -y_hat used for classification
    
'''
x_train, y_train, y_hat = create_pairs(x_train, y_train)

# %% [markdown]
# ## Setup models

# %%
nb = 64
input_shape = x_train.shape[1:]
encoder = models.cautrans_enc(input_shape, head_size=256, num_heads=3, num_f=256, dilations=[1,4,16], k_size=4, dropout=0.3)
projector = models.projector(input_shape=encoder.output_shape[1:], mlp_units=[128], mlp_dropout=0.3)

# %% [markdown]
# ## Modified SupCon Loss
#
# #### TRAIN

# %%
model = ContrastiveModel(encoder = encoder, projector=projector)
model.compile(e_optimizer=Adam(), e_loss_fn=supcon_loss)
lr = ReduceLROnPlateau(monitor='e_loss', factor=0.5, patience=5, min_lr=0.00001)
stop = tf.keras.callbacks.EarlyStopping(monitor='e_loss', patience=10, restore_best_weights=True)

# %%
s = time.time()
model.fit(x_train, y_train, epochs = 200, batch_size=nb*num_views, callbacks=[lr])
e = time.time()
# Out:
# Epoch 1/200
# 1/1 [==============================] - 4s 4s/step - e_loss: 4.8664 - lr: 0.0010
# Epoch 2/200
# 1/1 [==============================] - 0s 110ms/step - e_loss: 5.0896 - lr: 0.0010
# Epoch 3/200
# 1/1 [==============================] - 0s 110ms/step - e_loss: 4.5659 - lr: 0.0010
# Epoch 4/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 4.4732 - lr: 0.0010
# Epoch 5/200
# 1/1 [==============================] - 0s 110ms/step - e_loss: 4.5276 - lr: 0.0010
# Epoch 6/200
# 1/1 [==============================] - 0s 110ms/step - e_loss: 4.3954 - lr: 0.0010
# Epoch 7/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 4.3582 - lr: 0.0010
# Epoch 8/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 4.3990 - lr: 0.0010
# Epoch 9/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 4.3311 - lr: 0.0010
# Epoch 10/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 4.3036 - lr: 0.0010
# Epoch 11/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 4.2483 - lr: 0.0010
# Epoch 12/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 4.2344 - lr: 0.0010
# Epoch 13/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 4.2345 - lr: 0.0010
# Epoch 14/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 4.2245 - lr: 0.0010
# Epoch 15/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 4.1590 - lr: 0.0010
# Epoch 16/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 4.1349 - lr: 0.0010
# Epoch 17/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 4.1180 - lr: 0.0010
# Epoch 18/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 4.1131 - lr: 0.0010
# Epoch 19/200
# 1/1 [==============================] - 0s 110ms/step - e_loss: 4.0634 - lr: 0.0010
# Epoch 20/200
# 1/1 [==============================] - 0s 110ms/step - e_loss: 4.1026 - lr: 0.0010
# Epoch 21/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 4.0502 - lr: 0.0010
# Epoch 22/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 4.0514 - lr: 0.0010
# Epoch 23/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 4.0641 - lr: 0.0010
# Epoch 24/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 4.0746 - lr: 0.0010
# Epoch 25/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 4.0201 - lr: 0.0010
# Epoch 26/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 4.0138 - lr: 0.0010
# Epoch 27/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 4.0406 - lr: 0.0010
# Epoch 28/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.9803 - lr: 0.0010
# Epoch 29/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 4.0050 - lr: 0.0010
# Epoch 30/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 4.0086 - lr: 0.0010
# Epoch 31/200
# 1/1 [==============================] - 0s 110ms/step - e_loss: 3.9663 - lr: 0.0010
# Epoch 32/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.9662 - lr: 0.0010
# Epoch 33/200
# 1/1 [==============================] - 0s 110ms/step - e_loss: 3.9720 - lr: 0.0010
# Epoch 34/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.9820 - lr: 0.0010
# Epoch 35/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.9239 - lr: 0.0010
# Epoch 36/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.9646 - lr: 0.0010
# Epoch 37/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.9532 - lr: 0.0010
# Epoch 38/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.9506 - lr: 0.0010
# Epoch 39/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.9480 - lr: 0.0010
# Epoch 40/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.9844 - lr: 0.0010
# Epoch 41/200
# 1/1 [==============================] - 0s 110ms/step - e_loss: 3.9425 - lr: 5.0000e-04
# Epoch 42/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.9643 - lr: 5.0000e-04
# Epoch 43/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.9198 - lr: 5.0000e-04
# Epoch 44/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.9408 - lr: 5.0000e-04
# Epoch 45/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.9700 - lr: 5.0000e-04
# Epoch 46/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.9531 - lr: 5.0000e-04
# Epoch 47/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.9326 - lr: 5.0000e-04
# Epoch 48/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.9368 - lr: 5.0000e-04
# Epoch 49/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.9301 - lr: 2.5000e-04
# Epoch 50/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.9216 - lr: 2.5000e-04
# Epoch 51/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.9505 - lr: 2.5000e-04
# Epoch 52/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.9268 - lr: 2.5000e-04
# Epoch 53/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.9245 - lr: 2.5000e-04
# Epoch 54/200
# 1/1 [==============================] - 0s 110ms/step - e_loss: 3.9172 - lr: 1.2500e-04
# Epoch 55/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.9142 - lr: 1.2500e-04
# Epoch 56/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8884 - lr: 1.2500e-04
# Epoch 57/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.9138 - lr: 1.2500e-04
# Epoch 58/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8909 - lr: 1.2500e-04
# Epoch 59/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8896 - lr: 1.2500e-04
# Epoch 60/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.9165 - lr: 1.2500e-04
# Epoch 61/200
# 1/1 [==============================] - 0s 113ms/step - e_loss: 3.9170 - lr: 1.2500e-04
# Epoch 62/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.9314 - lr: 6.2500e-05
# Epoch 63/200
# 1/1 [==============================] - 0s 110ms/step - e_loss: 3.8944 - lr: 6.2500e-05
# Epoch 64/200
# 1/1 [==============================] - 0s 110ms/step - e_loss: 3.8982 - lr: 6.2500e-05
# Epoch 65/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8999 - lr: 6.2500e-05
# Epoch 66/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.9052 - lr: 6.2500e-05
# Epoch 67/200
# 1/1 [==============================] - 0s 110ms/step - e_loss: 3.8901 - lr: 3.1250e-05
# Epoch 68/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8798 - lr: 3.1250e-05
# Epoch 69/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8845 - lr: 3.1250e-05
# Epoch 70/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8850 - lr: 3.1250e-05
# Epoch 71/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.9052 - lr: 3.1250e-05
# Epoch 72/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.9002 - lr: 3.1250e-05
# Epoch 73/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8962 - lr: 3.1250e-05
# Epoch 74/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.9177 - lr: 1.5625e-05
# Epoch 75/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8611 - lr: 1.5625e-05
# Epoch 76/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8911 - lr: 1.5625e-05
# Epoch 77/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8668 - lr: 1.5625e-05
# Epoch 78/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8714 - lr: 1.5625e-05
# Epoch 79/200
# 1/1 [==============================] - 0s 110ms/step - e_loss: 3.8988 - lr: 1.5625e-05
# Epoch 80/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8677 - lr: 1.5625e-05
# Epoch 81/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8985 - lr: 1.0000e-05
# Epoch 82/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.9001 - lr: 1.0000e-05
# Epoch 83/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8837 - lr: 1.0000e-05
# Epoch 84/200
# 1/1 [==============================] - 0s 110ms/step - e_loss: 3.8637 - lr: 1.0000e-05
# Epoch 85/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8566 - lr: 1.0000e-05
# Epoch 86/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8695 - lr: 1.0000e-05
# Epoch 87/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8646 - lr: 1.0000e-05
# Epoch 88/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8740 - lr: 1.0000e-05
# Epoch 89/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8995 - lr: 1.0000e-05
# Epoch 90/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8560 - lr: 1.0000e-05
# Epoch 91/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8609 - lr: 1.0000e-05
# Epoch 92/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8682 - lr: 1.0000e-05
# Epoch 93/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8846 - lr: 1.0000e-05
# Epoch 94/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8582 - lr: 1.0000e-05
# Epoch 95/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8536 - lr: 1.0000e-05
# Epoch 96/200
# 1/1 [==============================] - 0s 113ms/step - e_loss: 3.8764 - lr: 1.0000e-05
# Epoch 97/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8816 - lr: 1.0000e-05
# Epoch 98/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8570 - lr: 1.0000e-05
# Epoch 99/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8522 - lr: 1.0000e-05
# Epoch 100/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8851 - lr: 1.0000e-05
# Epoch 101/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8747 - lr: 1.0000e-05
# Epoch 102/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8621 - lr: 1.0000e-05
# Epoch 103/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8682 - lr: 1.0000e-05
# Epoch 104/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8594 - lr: 1.0000e-05
# Epoch 105/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8818 - lr: 1.0000e-05
# Epoch 106/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8770 - lr: 1.0000e-05
# Epoch 107/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8456 - lr: 1.0000e-05
# Epoch 108/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8772 - lr: 1.0000e-05
# Epoch 109/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8279 - lr: 1.0000e-05
# Epoch 110/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8693 - lr: 1.0000e-05
# Epoch 111/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8219 - lr: 1.0000e-05
# Epoch 112/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8473 - lr: 1.0000e-05
# Epoch 113/200
# 1/1 [==============================] - 0s 110ms/step - e_loss: 3.8639 - lr: 1.0000e-05
# Epoch 114/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8548 - lr: 1.0000e-05
# Epoch 115/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8602 - lr: 1.0000e-05
# Epoch 116/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8481 - lr: 1.0000e-05
# Epoch 117/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8687 - lr: 1.0000e-05
# Epoch 118/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8571 - lr: 1.0000e-05
# Epoch 119/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8448 - lr: 1.0000e-05
# Epoch 120/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8446 - lr: 1.0000e-05
# Epoch 121/200
# 1/1 [==============================] - 0s 110ms/step - e_loss: 3.8729 - lr: 1.0000e-05
# Epoch 122/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8616 - lr: 1.0000e-05
# Epoch 123/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8246 - lr: 1.0000e-05
# Epoch 124/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8680 - lr: 1.0000e-05
# Epoch 125/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8371 - lr: 1.0000e-05
# Epoch 126/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8450 - lr: 1.0000e-05
# Epoch 127/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8650 - lr: 1.0000e-05
# Epoch 128/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8531 - lr: 1.0000e-05
# Epoch 129/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8705 - lr: 1.0000e-05
# Epoch 130/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8340 - lr: 1.0000e-05
# Epoch 131/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8631 - lr: 1.0000e-05
# Epoch 132/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8257 - lr: 1.0000e-05
# Epoch 133/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8563 - lr: 1.0000e-05
# Epoch 134/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8377 - lr: 1.0000e-05
# Epoch 135/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8347 - lr: 1.0000e-05
# Epoch 136/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8617 - lr: 1.0000e-05
# Epoch 137/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8249 - lr: 1.0000e-05
# Epoch 138/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8119 - lr: 1.0000e-05
# Epoch 139/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8434 - lr: 1.0000e-05
# Epoch 140/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8243 - lr: 1.0000e-05
# Epoch 141/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8277 - lr: 1.0000e-05
# Epoch 142/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8346 - lr: 1.0000e-05
# Epoch 143/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8778 - lr: 1.0000e-05
# Epoch 144/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8386 - lr: 1.0000e-05
# Epoch 145/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8296 - lr: 1.0000e-05
# Epoch 146/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8388 - lr: 1.0000e-05
# Epoch 147/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8357 - lr: 1.0000e-05
# Epoch 148/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8503 - lr: 1.0000e-05
# Epoch 149/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8418 - lr: 1.0000e-05
# Epoch 150/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8453 - lr: 1.0000e-05
# Epoch 151/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8349 - lr: 1.0000e-05
# Epoch 152/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8313 - lr: 1.0000e-05
# Epoch 153/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8492 - lr: 1.0000e-05
# Epoch 154/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8209 - lr: 1.0000e-05
# Epoch 155/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8228 - lr: 1.0000e-05
# Epoch 156/200
# 1/1 [==============================] - 0s 110ms/step - e_loss: 3.8322 - lr: 1.0000e-05
# Epoch 157/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8202 - lr: 1.0000e-05
# Epoch 158/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8418 - lr: 1.0000e-05
# Epoch 159/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8183 - lr: 1.0000e-05
# Epoch 160/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8395 - lr: 1.0000e-05
# Epoch 161/200
# 1/1 [==============================] - 0s 109ms/step - e_loss: 3.8414 - lr: 1.0000e-05
# Epoch 162/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8248 - lr: 1.0000e-05
# Epoch 163/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8276 - lr: 1.0000e-05
# Epoch 164/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8258 - lr: 1.0000e-05
# Epoch 165/200
# 1/1 [==============================] - 0s 110ms/step - e_loss: 3.8115 - lr: 1.0000e-05
# Epoch 166/200
# 1/1 [==============================] - 0s 110ms/step - e_loss: 3.8292 - lr: 1.0000e-05
# Epoch 167/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8123 - lr: 1.0000e-05
# Epoch 168/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8436 - lr: 1.0000e-05
# Epoch 169/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8524 - lr: 1.0000e-05
# Epoch 170/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8177 - lr: 1.0000e-05
# Epoch 171/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8169 - lr: 1.0000e-05
# Epoch 172/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8181 - lr: 1.0000e-05
# Epoch 173/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8177 - lr: 1.0000e-05
# Epoch 174/200
# 1/1 [==============================] - 0s 109ms/step - e_loss: 3.8091 - lr: 1.0000e-05
# Epoch 175/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8003 - lr: 1.0000e-05
# Epoch 176/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8407 - lr: 1.0000e-05
# Epoch 177/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8568 - lr: 1.0000e-05
# Epoch 178/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8089 - lr: 1.0000e-05
# Epoch 179/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8249 - lr: 1.0000e-05
# Epoch 180/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8203 - lr: 1.0000e-05
# Epoch 181/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8069 - lr: 1.0000e-05
# Epoch 182/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8190 - lr: 1.0000e-05
# Epoch 183/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8287 - lr: 1.0000e-05
# Epoch 184/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8581 - lr: 1.0000e-05
# Epoch 185/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8438 - lr: 1.0000e-05
# Epoch 186/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8135 - lr: 1.0000e-05
# Epoch 187/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8139 - lr: 1.0000e-05
# Epoch 188/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8172 - lr: 1.0000e-05
# Epoch 189/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.7995 - lr: 1.0000e-05
# Epoch 190/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8428 - lr: 1.0000e-05
# Epoch 191/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8307 - lr: 1.0000e-05
# Epoch 192/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8270 - lr: 1.0000e-05
# Epoch 193/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8153 - lr: 1.0000e-05
# Epoch 194/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8081 - lr: 1.0000e-05
# Epoch 195/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8239 - lr: 1.0000e-05
# Epoch 196/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8326 - lr: 1.0000e-05
# Epoch 197/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8204 - lr: 1.0000e-05
# Epoch 198/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8103 - lr: 1.0000e-05
# Epoch 199/200
# 1/1 [==============================] - 0s 113ms/step - e_loss: 3.8214 - lr: 1.0000e-05
# Epoch 200/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8341 - lr: 1.0000e-05

# %%
e-s
# Out:
# 26.868256092071533

# %% [markdown]
# #### TEST

# %%
tr_feat = model.encoder.predict(x_train)
te_feat = model.encoder.predict(x_test)
proj_tr = model.projector.predict(tr_feat)
proj_te = model.projector.predict(te_feat)

# %%
y_train = np.squeeze(y_train)
classifier = models.MLP_cl(input_dim=tr_feat.shape[1], mlp_layers=[256, 64], n_class=n_class)
classifier.compile(optimizer=Adam(learning_rate=1e-03), 
                   loss='sparse_categorical_crossentropy', 
                   metrics=["sparse_categorical_accuracy"]
                  )
callbacks = [tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)]
classifier.fit(tr_feat, y_train, epochs=200, batch_size=64, validation_split=0.1, callbacks=callbacks)
# Out:
# Epoch 1/200
# 2/2 [==============================] - 0s 114ms/step - loss: 1.2652 - sparse_categorical_accuracy: 0.3889 - val_loss: 0.7823 - val_sparse_categorical_accuracy: 0.6667
# Epoch 2/200
# 2/2 [==============================] - 0s 21ms/step - loss: 0.9094 - sparse_categorical_accuracy: 0.5556 - val_loss: 0.5490 - val_sparse_categorical_accuracy: 1.0000
# Epoch 3/200
# 2/2 [==============================] - 0s 24ms/step - loss: 0.6722 - sparse_categorical_accuracy: 0.7037 - val_loss: 0.4160 - val_sparse_categorical_accuracy: 1.0000
# Epoch 4/200
# 2/2 [==============================] - 0s 25ms/step - loss: 0.5211 - sparse_categorical_accuracy: 0.8611 - val_loss: 0.3339 - val_sparse_categorical_accuracy: 1.0000
# Epoch 5/200
# 2/2 [==============================] - 0s 24ms/step - loss: 0.4344 - sparse_categorical_accuracy: 0.8519 - val_loss: 0.2661 - val_sparse_categorical_accuracy: 1.0000
# Epoch 6/200
# 2/2 [==============================] - 0s 25ms/step - loss: 0.3587 - sparse_categorical_accuracy: 0.8796 - val_loss: 0.2223 - val_sparse_categorical_accuracy: 1.0000
# Epoch 7/200
# 2/2 [==============================] - 0s 23ms/step - loss: 0.3252 - sparse_categorical_accuracy: 0.8704 - val_loss: 0.1907 - val_sparse_categorical_accuracy: 1.0000
# Epoch 8/200
# 2/2 [==============================] - 0s 24ms/step - loss: 0.2713 - sparse_categorical_accuracy: 0.8981 - val_loss: 0.1626 - val_sparse_categorical_accuracy: 1.0000
# Epoch 9/200
# 2/2 [==============================] - 0s 24ms/step - loss: 0.2565 - sparse_categorical_accuracy: 0.8981 - val_loss: 0.1318 - val_sparse_categorical_accuracy: 1.0000
# Epoch 10/200
# 2/2 [==============================] - 0s 24ms/step - loss: 0.2249 - sparse_categorical_accuracy: 0.9074 - val_loss: 0.1189 - val_sparse_categorical_accuracy: 1.0000
# Epoch 11/200
# 2/2 [==============================] - 0s 26ms/step - loss: 0.2501 - sparse_categorical_accuracy: 0.8981 - val_loss: 0.1078 - val_sparse_categorical_accuracy: 1.0000
# Epoch 12/200
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1652 - sparse_categorical_accuracy: 0.9352 - val_loss: 0.0914 - val_sparse_categorical_accuracy: 1.0000
# Epoch 13/200
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1307 - sparse_categorical_accuracy: 0.9444 - val_loss: 0.0741 - val_sparse_categorical_accuracy: 1.0000
# Epoch 14/200
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1680 - sparse_categorical_accuracy: 0.9167 - val_loss: 0.0663 - val_sparse_categorical_accuracy: 1.0000
# Epoch 15/200
# 2/2 [==============================] - 0s 20ms/step - loss: 0.1181 - sparse_categorical_accuracy: 0.9630 - val_loss: 0.0692 - val_sparse_categorical_accuracy: 1.0000
# Epoch 16/200
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1282 - sparse_categorical_accuracy: 0.9630 - val_loss: 0.0527 - val_sparse_categorical_accuracy: 1.0000
# Epoch 17/200
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0712 - sparse_categorical_accuracy: 0.9815 - val_loss: 0.0381 - val_sparse_categorical_accuracy: 1.0000
# Epoch 18/200
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0545 - sparse_categorical_accuracy: 0.9907 - val_loss: 0.0330 - val_sparse_categorical_accuracy: 1.0000
# Epoch 19/200
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0460 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0294 - val_sparse_categorical_accuracy: 1.0000
# Epoch 20/200
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0695 - sparse_categorical_accuracy: 0.9815 - val_loss: 0.0244 - val_sparse_categorical_accuracy: 1.0000
# Epoch 21/200
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0473 - sparse_categorical_accuracy: 0.9907 - val_loss: 0.0324 - val_sparse_categorical_accuracy: 1.0000
# Epoch 22/200
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0602 - sparse_categorical_accuracy: 0.9815 - val_loss: 0.0659 - val_sparse_categorical_accuracy: 1.0000
# Epoch 23/200
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0471 - sparse_categorical_accuracy: 0.9815 - val_loss: 0.0597 - val_sparse_categorical_accuracy: 1.0000
# Epoch 24/200
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0352 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0310 - val_sparse_categorical_accuracy: 1.0000
# Epoch 25/200
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0624 - sparse_categorical_accuracy: 0.9722 - val_loss: 0.0106 - val_sparse_categorical_accuracy: 1.0000
# Epoch 26/200
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0267 - sparse_categorical_accuracy: 0.9907 - val_loss: 0.0095 - val_sparse_categorical_accuracy: 1.0000
# Epoch 27/200
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0272 - sparse_categorical_accuracy: 0.9907 - val_loss: 0.0102 - val_sparse_categorical_accuracy: 1.0000
# Epoch 28/200
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0251 - sparse_categorical_accuracy: 0.9907 - val_loss: 0.0070 - val_sparse_categorical_accuracy: 1.0000
# Epoch 29/200
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0263 - sparse_categorical_accuracy: 0.9907 - val_loss: 0.0059 - val_sparse_categorical_accuracy: 1.0000
# Epoch 30/200
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0300 - sparse_categorical_accuracy: 0.9907 - val_loss: 0.0128 - val_sparse_categorical_accuracy: 1.0000
# Epoch 31/200
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0148 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0281 - val_sparse_categorical_accuracy: 1.0000
# Epoch 32/200
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0386 - sparse_categorical_accuracy: 0.9815 - val_loss: 0.0213 - val_sparse_categorical_accuracy: 1.0000
# Epoch 33/200
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0144 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0120 - val_sparse_categorical_accuracy: 1.0000
# Epoch 34/200
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0341 - sparse_categorical_accuracy: 0.9907 - val_loss: 0.0062 - val_sparse_categorical_accuracy: 1.0000
# Epoch 35/200
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0202 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0031 - val_sparse_categorical_accuracy: 1.0000
# Epoch 36/200
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0137 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0025 - val_sparse_categorical_accuracy: 1.0000
# Epoch 37/200
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0198 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0022 - val_sparse_categorical_accuracy: 1.0000
# Epoch 38/200
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0150 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0021 - val_sparse_categorical_accuracy: 1.0000
# Epoch 39/200
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0205 - sparse_categorical_accuracy: 0.9907 - val_loss: 0.0026 - val_sparse_categorical_accuracy: 1.0000
# Epoch 40/200
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0123 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0047 - val_sparse_categorical_accuracy: 1.0000
# Epoch 41/200
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0168 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0089 - val_sparse_categorical_accuracy: 1.0000
# Epoch 42/200
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0173 - sparse_categorical_accuracy: 0.9907 - val_loss: 0.0102 - val_sparse_categorical_accuracy: 1.0000
# Epoch 43/200
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0135 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0055 - val_sparse_categorical_accuracy: 1.0000
# Epoch 44/200
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0121 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0025 - val_sparse_categorical_accuracy: 1.0000
# Epoch 45/200
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0117 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0016 - val_sparse_categorical_accuracy: 1.0000
# Epoch 46/200
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0109 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0012 - val_sparse_categorical_accuracy: 1.0000
# Epoch 47/200
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0111 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0012 - val_sparse_categorical_accuracy: 1.0000
# Epoch 48/200
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0133 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0015 - val_sparse_categorical_accuracy: 1.0000
# Epoch 49/200
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0084 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0023 - val_sparse_categorical_accuracy: 1.0000
# Epoch 50/200
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0070 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0043 - val_sparse_categorical_accuracy: 1.0000
# Epoch 51/200
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0029 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0071 - val_sparse_categorical_accuracy: 1.0000
# Epoch 52/200
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0127 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0106 - val_sparse_categorical_accuracy: 1.0000
# Epoch 53/200
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0080 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0100 - val_sparse_categorical_accuracy: 1.0000
# Epoch 54/200
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0064 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0071 - val_sparse_categorical_accuracy: 1.0000
# Epoch 55/200
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0098 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0031 - val_sparse_categorical_accuracy: 1.0000
# Epoch 56/200
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0069 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0019 - val_sparse_categorical_accuracy: 1.0000
# Epoch 57/200
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0064 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0013 - val_sparse_categorical_accuracy: 1.0000

# %%
classifier.evaluate(te_feat, y_test)
# Out:
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0772 - sparse_categorical_accuracy: 0.9667
# [0.07722572237253189, 0.9666666388511658]

# %% [markdown]
# ## Original SupCon Loss
#
# #### TRAIN

# %%
model_ori = ContrastiveModel_ori(encoder = encoder, projector=projector)
model_ori.compile(e_optimizer=Adam(), e_loss_fn=supcon_loss_ori)
lr = ReduceLROnPlateau(monitor='e_loss', factor=0.5, patience=5, min_lr=0.00001)

# %%
n, t, d = x_train.shape
x_train_ori = np.reshape(x_train, [int(n/num_views), num_views, t, d])
y_train_ori = y_train.reshape([int(y_train.shape[0]/num_views), num_views])[:, 0]
y_train_ori = np.expand_dims(y_train_ori, axis=-1)
s = time.time()
model_ori.fit(x_train_ori, y_train_ori, epochs = 200, batch_size=nb, callbacks=[lr])
e = time.time()
# Out:
# Epoch 1/200
# 1/1 [==============================] - 1s 1s/step - e_loss: 3.8205 - lr: 0.0010
# Epoch 2/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8767 - lr: 0.0010
# Epoch 3/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8594 - lr: 0.0010
# Epoch 4/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8897 - lr: 0.0010
# Epoch 5/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8120 - lr: 0.0010
# Epoch 6/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8338 - lr: 0.0010
# Epoch 7/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8336 - lr: 0.0010
# Epoch 8/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8397 - lr: 0.0010
# Epoch 9/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8303 - lr: 0.0010
# Epoch 10/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8417 - lr: 0.0010
# Epoch 11/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8312 - lr: 5.0000e-04
# Epoch 12/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8411 - lr: 5.0000e-04
# Epoch 13/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8371 - lr: 5.0000e-04
# Epoch 14/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8229 - lr: 5.0000e-04
# Epoch 15/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8286 - lr: 5.0000e-04
# Epoch 16/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8173 - lr: 2.5000e-04
# Epoch 17/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8048 - lr: 2.5000e-04
# Epoch 18/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8201 - lr: 2.5000e-04
# Epoch 19/200
# 1/1 [==============================] - 0s 113ms/step - e_loss: 3.8165 - lr: 2.5000e-04
# Epoch 20/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8414 - lr: 2.5000e-04
# Epoch 21/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8049 - lr: 2.5000e-04
# Epoch 22/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8197 - lr: 2.5000e-04
# Epoch 23/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8226 - lr: 1.2500e-04
# Epoch 24/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8153 - lr: 1.2500e-04
# Epoch 25/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8111 - lr: 1.2500e-04
# Epoch 26/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8267 - lr: 1.2500e-04
# Epoch 27/200
# 1/1 [==============================] - 0s 113ms/step - e_loss: 3.8154 - lr: 1.2500e-04
# Epoch 28/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8018 - lr: 6.2500e-05
# Epoch 29/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8283 - lr: 6.2500e-05
# Epoch 30/200
# 1/1 [==============================] - 0s 113ms/step - e_loss: 3.8044 - lr: 6.2500e-05
# Epoch 31/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8402 - lr: 6.2500e-05
# Epoch 32/200
# 1/1 [==============================] - 0s 113ms/step - e_loss: 3.8163 - lr: 6.2500e-05
# Epoch 33/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8391 - lr: 6.2500e-05
# Epoch 34/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8283 - lr: 3.1250e-05
# Epoch 35/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.7978 - lr: 3.1250e-05
# Epoch 36/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8174 - lr: 3.1250e-05
# Epoch 37/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8310 - lr: 3.1250e-05
# Epoch 38/200
# 1/1 [==============================] - 0s 113ms/step - e_loss: 3.8446 - lr: 3.1250e-05
# Epoch 39/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8139 - lr: 3.1250e-05
# Epoch 40/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8183 - lr: 3.1250e-05
# Epoch 41/200
# 1/1 [==============================] - 0s 113ms/step - e_loss: 3.7905 - lr: 1.5625e-05
# Epoch 42/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8075 - lr: 1.5625e-05
# Epoch 43/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8127 - lr: 1.5625e-05
# Epoch 44/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8182 - lr: 1.5625e-05
# Epoch 45/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8097 - lr: 1.5625e-05
# Epoch 46/200
# 1/1 [==============================] - 0s 113ms/step - e_loss: 3.8012 - lr: 1.5625e-05
# Epoch 47/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8115 - lr: 1.0000e-05
# Epoch 48/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.7901 - lr: 1.0000e-05
# Epoch 49/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8242 - lr: 1.0000e-05
# Epoch 50/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8064 - lr: 1.0000e-05
# Epoch 51/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8350 - lr: 1.0000e-05
# Epoch 52/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8053 - lr: 1.0000e-05
# Epoch 53/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8351 - lr: 1.0000e-05
# Epoch 54/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8185 - lr: 1.0000e-05
# Epoch 55/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8095 - lr: 1.0000e-05
# Epoch 56/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8286 - lr: 1.0000e-05
# Epoch 57/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8252 - lr: 1.0000e-05
# Epoch 58/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8248 - lr: 1.0000e-05
# Epoch 59/200
# 1/1 [==============================] - 0s 110ms/step - e_loss: 3.8005 - lr: 1.0000e-05
# Epoch 60/200
# 1/1 [==============================] - 0s 113ms/step - e_loss: 3.8099 - lr: 1.0000e-05
# Epoch 61/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8165 - lr: 1.0000e-05
# Epoch 62/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8026 - lr: 1.0000e-05
# Epoch 63/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.7922 - lr: 1.0000e-05
# Epoch 64/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.7857 - lr: 1.0000e-05
# Epoch 65/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8020 - lr: 1.0000e-05
# Epoch 66/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8082 - lr: 1.0000e-05
# Epoch 67/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.7956 - lr: 1.0000e-05
# Epoch 68/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8085 - lr: 1.0000e-05
# Epoch 69/200
# 1/1 [==============================] - 0s 113ms/step - e_loss: 3.8242 - lr: 1.0000e-05
# Epoch 70/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8116 - lr: 1.0000e-05
# Epoch 71/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.7852 - lr: 1.0000e-05
# Epoch 72/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8046 - lr: 1.0000e-05
# Epoch 73/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8103 - lr: 1.0000e-05
# Epoch 74/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8173 - lr: 1.0000e-05
# Epoch 75/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8144 - lr: 1.0000e-05
# Epoch 76/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.7932 - lr: 1.0000e-05
# Epoch 77/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8046 - lr: 1.0000e-05
# Epoch 78/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8088 - lr: 1.0000e-05
# Epoch 79/200
# 1/1 [==============================] - 0s 113ms/step - e_loss: 3.8008 - lr: 1.0000e-05
# Epoch 80/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8110 - lr: 1.0000e-05
# Epoch 81/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8281 - lr: 1.0000e-05
# Epoch 82/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8304 - lr: 1.0000e-05
# Epoch 83/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8068 - lr: 1.0000e-05
# Epoch 84/200
# 1/1 [==============================] - 0s 113ms/step - e_loss: 3.7979 - lr: 1.0000e-05
# Epoch 85/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.7815 - lr: 1.0000e-05
# Epoch 86/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.7936 - lr: 1.0000e-05
# Epoch 87/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.7907 - lr: 1.0000e-05
# Epoch 88/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.7985 - lr: 1.0000e-05
# Epoch 89/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8104 - lr: 1.0000e-05
# Epoch 90/200
# 1/1 [==============================] - 0s 113ms/step - e_loss: 3.7820 - lr: 1.0000e-05
# Epoch 91/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8191 - lr: 1.0000e-05
# Epoch 92/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8243 - lr: 1.0000e-05
# Epoch 93/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.7865 - lr: 1.0000e-05
# Epoch 94/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8340 - lr: 1.0000e-05
# Epoch 95/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8032 - lr: 1.0000e-05
# Epoch 96/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8205 - lr: 1.0000e-05
# Epoch 97/200
# 1/1 [==============================] - 0s 110ms/step - e_loss: 3.7987 - lr: 1.0000e-05
# Epoch 98/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8008 - lr: 1.0000e-05
# Epoch 99/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.7875 - lr: 1.0000e-05
# Epoch 100/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.7777 - lr: 1.0000e-05
# Epoch 101/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.7995 - lr: 1.0000e-05
# Epoch 102/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8119 - lr: 1.0000e-05
# Epoch 103/200
# 1/1 [==============================] - 0s 113ms/step - e_loss: 3.8113 - lr: 1.0000e-05
# Epoch 104/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8111 - lr: 1.0000e-05
# Epoch 105/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.7954 - lr: 1.0000e-05
# Epoch 106/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8084 - lr: 1.0000e-05
# Epoch 107/200
# 1/1 [==============================] - 0s 113ms/step - e_loss: 3.7763 - lr: 1.0000e-05
# Epoch 108/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.7856 - lr: 1.0000e-05
# Epoch 109/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8026 - lr: 1.0000e-05
# Epoch 110/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.7870 - lr: 1.0000e-05
# Epoch 111/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.7861 - lr: 1.0000e-05
# Epoch 112/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.7984 - lr: 1.0000e-05
# Epoch 113/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8089 - lr: 1.0000e-05
# Epoch 114/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.7927 - lr: 1.0000e-05
# Epoch 115/200
# 1/1 [==============================] - 0s 113ms/step - e_loss: 3.8141 - lr: 1.0000e-05
# Epoch 116/200
# 1/1 [==============================] - 0s 113ms/step - e_loss: 3.7922 - lr: 1.0000e-05
# Epoch 117/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.7965 - lr: 1.0000e-05
# Epoch 118/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8007 - lr: 1.0000e-05
# Epoch 119/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.7975 - lr: 1.0000e-05
# Epoch 120/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.7792 - lr: 1.0000e-05
# Epoch 121/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.7858 - lr: 1.0000e-05
# Epoch 122/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.7919 - lr: 1.0000e-05
# Epoch 123/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8041 - lr: 1.0000e-05
# Epoch 124/200
# 1/1 [==============================] - 0s 113ms/step - e_loss: 3.7781 - lr: 1.0000e-05
# Epoch 125/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.7997 - lr: 1.0000e-05
# Epoch 126/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.7937 - lr: 1.0000e-05
# Epoch 127/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.7723 - lr: 1.0000e-05
# Epoch 128/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.7789 - lr: 1.0000e-05
# Epoch 129/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8051 - lr: 1.0000e-05
# Epoch 130/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8117 - lr: 1.0000e-05
# Epoch 131/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.7962 - lr: 1.0000e-05
# Epoch 132/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8014 - lr: 1.0000e-05
# Epoch 133/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.7813 - lr: 1.0000e-05
# Epoch 134/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.7941 - lr: 1.0000e-05
# Epoch 135/200
# 1/1 [==============================] - 0s 113ms/step - e_loss: 3.8067 - lr: 1.0000e-05
# Epoch 136/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.7895 - lr: 1.0000e-05
# Epoch 137/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.7820 - lr: 1.0000e-05
# Epoch 138/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8109 - lr: 1.0000e-05
# Epoch 139/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.7977 - lr: 1.0000e-05
# Epoch 140/200
# 1/1 [==============================] - 0s 113ms/step - e_loss: 3.7842 - lr: 1.0000e-05
# Epoch 141/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.7885 - lr: 1.0000e-05
# Epoch 142/200
# 1/1 [==============================] - 0s 113ms/step - e_loss: 3.7757 - lr: 1.0000e-05
# Epoch 143/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.7976 - lr: 1.0000e-05
# Epoch 144/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8005 - lr: 1.0000e-05
# Epoch 145/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.7914 - lr: 1.0000e-05
# Epoch 146/200
# 1/1 [==============================] - 0s 113ms/step - e_loss: 3.7726 - lr: 1.0000e-05
# Epoch 147/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.7850 - lr: 1.0000e-05
# Epoch 148/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.7923 - lr: 1.0000e-05
# Epoch 149/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.7990 - lr: 1.0000e-05
# Epoch 150/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.7982 - lr: 1.0000e-05
# Epoch 151/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8045 - lr: 1.0000e-05
# Epoch 152/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8035 - lr: 1.0000e-05
# Epoch 153/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8199 - lr: 1.0000e-05
# Epoch 154/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.7981 - lr: 1.0000e-05
# Epoch 155/200
# 1/1 [==============================] - 0s 113ms/step - e_loss: 3.7824 - lr: 1.0000e-05
# Epoch 156/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.7974 - lr: 1.0000e-05
# Epoch 157/200
# 1/1 [==============================] - 0s 113ms/step - e_loss: 3.8216 - lr: 1.0000e-05
# Epoch 158/200
# 1/1 [==============================] - 0s 113ms/step - e_loss: 3.7980 - lr: 1.0000e-05
# Epoch 159/200
# 1/1 [==============================] - 0s 113ms/step - e_loss: 3.8053 - lr: 1.0000e-05
# Epoch 160/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.7821 - lr: 1.0000e-05
# Epoch 161/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8000 - lr: 1.0000e-05
# Epoch 162/200
# 1/1 [==============================] - 0s 113ms/step - e_loss: 3.8099 - lr: 1.0000e-05
# Epoch 163/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.7962 - lr: 1.0000e-05
# Epoch 164/200
# 1/1 [==============================] - 0s 113ms/step - e_loss: 3.7963 - lr: 1.0000e-05
# Epoch 165/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.7904 - lr: 1.0000e-05
# Epoch 166/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8065 - lr: 1.0000e-05
# Epoch 167/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.7940 - lr: 1.0000e-05
# Epoch 168/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.7854 - lr: 1.0000e-05
# Epoch 169/200
# 1/1 [==============================] - 0s 113ms/step - e_loss: 3.7881 - lr: 1.0000e-05
# Epoch 170/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.7600 - lr: 1.0000e-05
# Epoch 171/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8063 - lr: 1.0000e-05
# Epoch 172/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.7925 - lr: 1.0000e-05
# Epoch 173/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.7973 - lr: 1.0000e-05
# Epoch 174/200
# 1/1 [==============================] - 0s 113ms/step - e_loss: 3.8201 - lr: 1.0000e-05
# Epoch 175/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.7996 - lr: 1.0000e-05
# Epoch 176/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.7966 - lr: 1.0000e-05
# Epoch 177/200
# 1/1 [==============================] - 0s 113ms/step - e_loss: 3.7914 - lr: 1.0000e-05
# Epoch 178/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.7828 - lr: 1.0000e-05
# Epoch 179/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.8020 - lr: 1.0000e-05
# Epoch 180/200
# 1/1 [==============================] - 0s 113ms/step - e_loss: 3.7830 - lr: 1.0000e-05
# Epoch 181/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.7861 - lr: 1.0000e-05
# Epoch 182/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.7865 - lr: 1.0000e-05
# Epoch 183/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.7963 - lr: 1.0000e-05
# Epoch 184/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8049 - lr: 1.0000e-05
# Epoch 185/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.7871 - lr: 1.0000e-05
# Epoch 186/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.7871 - lr: 1.0000e-05
# Epoch 187/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.7893 - lr: 1.0000e-05
# Epoch 188/200
# 1/1 [==============================] - 0s 113ms/step - e_loss: 3.7866 - lr: 1.0000e-05
# Epoch 189/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8133 - lr: 1.0000e-05
# Epoch 190/200
# 1/1 [==============================] - 0s 110ms/step - e_loss: 3.8042 - lr: 1.0000e-05
# Epoch 191/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.7895 - lr: 1.0000e-05
# Epoch 192/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8024 - lr: 1.0000e-05
# Epoch 193/200
# 1/1 [==============================] - 0s 114ms/step - e_loss: 3.7916 - lr: 1.0000e-05
# Epoch 194/200
# 1/1 [==============================] - 0s 113ms/step - e_loss: 3.7749 - lr: 1.0000e-05
# Epoch 195/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.7903 - lr: 1.0000e-05
# Epoch 196/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.7956 - lr: 1.0000e-05
# Epoch 197/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.7890 - lr: 1.0000e-05
# Epoch 198/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.8103 - lr: 1.0000e-05
# Epoch 199/200
# 1/1 [==============================] - 0s 111ms/step - e_loss: 3.7904 - lr: 1.0000e-05
# Epoch 200/200
# 1/1 [==============================] - 0s 112ms/step - e_loss: 3.7730 - lr: 1.0000e-05

# %%
e-s
# Out:
# 28.424842834472656

# %% [markdown]
# #### TEST

# %%
tr_feat = model_ori.encoder.predict(x_train)
te_feat = model_ori.encoder.predict(x_test)
proj_tr = model_ori.projector.predict(tr_feat)
proj_te = model_ori.projector.predict(te_feat)

# %%
y_train = np.squeeze(y_train)
classifier = models.MLP_cl(input_dim=tr_feat.shape[1], mlp_layers=[256, 64], n_class=n_class)
classifier.compile(optimizer=Adam(learning_rate=1e-03), 
                   loss='sparse_categorical_crossentropy', 
                   metrics=["sparse_categorical_accuracy"]
                  )
callbacks = [tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)]
classifier.fit(tr_feat, y_train, epochs=200, batch_size=64, validation_split=0.1, callbacks=callbacks)
# Out:
# Epoch 1/200
# 2/2 [==============================] - 0s 90ms/step - loss: 1.0635 - sparse_categorical_accuracy: 0.4352 - val_loss: 0.6749 - val_sparse_categorical_accuracy: 0.8333
# Epoch 2/200
# 2/2 [==============================] - 0s 25ms/step - loss: 0.6827 - sparse_categorical_accuracy: 0.7500 - val_loss: 0.4633 - val_sparse_categorical_accuracy: 0.8333
# Epoch 3/200
# 2/2 [==============================] - 0s 24ms/step - loss: 0.5187 - sparse_categorical_accuracy: 0.8056 - val_loss: 0.3443 - val_sparse_categorical_accuracy: 1.0000
# Epoch 4/200
# 2/2 [==============================] - 0s 23ms/step - loss: 0.4506 - sparse_categorical_accuracy: 0.8333 - val_loss: 0.2403 - val_sparse_categorical_accuracy: 1.0000
# Epoch 5/200
# 2/2 [==============================] - 0s 28ms/step - loss: 0.3395 - sparse_categorical_accuracy: 0.8889 - val_loss: 0.1841 - val_sparse_categorical_accuracy: 1.0000
# Epoch 6/200
# 2/2 [==============================] - 0s 24ms/step - loss: 0.2681 - sparse_categorical_accuracy: 0.8981 - val_loss: 0.1488 - val_sparse_categorical_accuracy: 1.0000
# Epoch 7/200
# 2/2 [==============================] - 0s 25ms/step - loss: 0.2734 - sparse_categorical_accuracy: 0.8889 - val_loss: 0.1207 - val_sparse_categorical_accuracy: 1.0000
# Epoch 8/200
# 2/2 [==============================] - 0s 22ms/step - loss: 0.2257 - sparse_categorical_accuracy: 0.9259 - val_loss: 0.0948 - val_sparse_categorical_accuracy: 1.0000
# Epoch 9/200
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1522 - sparse_categorical_accuracy: 0.9722 - val_loss: 0.0719 - val_sparse_categorical_accuracy: 1.0000
# Epoch 10/200
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1621 - sparse_categorical_accuracy: 0.9352 - val_loss: 0.0739 - val_sparse_categorical_accuracy: 1.0000
# Epoch 11/200
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1370 - sparse_categorical_accuracy: 0.9815 - val_loss: 0.0710 - val_sparse_categorical_accuracy: 1.0000
# Epoch 12/200
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1067 - sparse_categorical_accuracy: 0.9630 - val_loss: 0.0520 - val_sparse_categorical_accuracy: 1.0000
# Epoch 13/200
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0905 - sparse_categorical_accuracy: 0.9722 - val_loss: 0.0281 - val_sparse_categorical_accuracy: 1.0000
# Epoch 14/200
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0856 - sparse_categorical_accuracy: 0.9722 - val_loss: 0.0209 - val_sparse_categorical_accuracy: 1.0000
# Epoch 15/200
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0374 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0168 - val_sparse_categorical_accuracy: 1.0000
# Epoch 16/200
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0381 - sparse_categorical_accuracy: 0.9907 - val_loss: 0.0176 - val_sparse_categorical_accuracy: 1.0000
# Epoch 17/200
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0494 - sparse_categorical_accuracy: 0.9815 - val_loss: 0.0258 - val_sparse_categorical_accuracy: 1.0000
# Epoch 18/200
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0737 - sparse_categorical_accuracy: 0.9722 - val_loss: 0.0344 - val_sparse_categorical_accuracy: 1.0000
# Epoch 19/200
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0479 - sparse_categorical_accuracy: 0.9907 - val_loss: 0.0281 - val_sparse_categorical_accuracy: 1.0000
# Epoch 20/200
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0418 - sparse_categorical_accuracy: 0.9907 - val_loss: 0.0194 - val_sparse_categorical_accuracy: 1.0000
# Epoch 21/200
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0207 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0125 - val_sparse_categorical_accuracy: 1.0000
# Epoch 22/200
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0252 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0071 - val_sparse_categorical_accuracy: 1.0000
# Epoch 23/200
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0261 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0048 - val_sparse_categorical_accuracy: 1.0000
# Epoch 24/200
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0183 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0042 - val_sparse_categorical_accuracy: 1.0000
# Epoch 25/200
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0131 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0038 - val_sparse_categorical_accuracy: 1.0000
# Epoch 26/200
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0242 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0028 - val_sparse_categorical_accuracy: 1.0000
# Epoch 27/200
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0165 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0023 - val_sparse_categorical_accuracy: 1.0000
# Epoch 28/200
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0154 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0022 - val_sparse_categorical_accuracy: 1.0000
# Epoch 29/200
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0208 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0027 - val_sparse_categorical_accuracy: 1.0000
# Epoch 30/200
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0050 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0033 - val_sparse_categorical_accuracy: 1.0000
# Epoch 31/200
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0115 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0038 - val_sparse_categorical_accuracy: 1.0000
# Epoch 32/200
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0036 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0045 - val_sparse_categorical_accuracy: 1.0000
# Epoch 33/200
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0039 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0051 - val_sparse_categorical_accuracy: 1.0000
# Epoch 34/200
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0056 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0056 - val_sparse_categorical_accuracy: 1.0000
# Epoch 35/200
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0139 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0046 - val_sparse_categorical_accuracy: 1.0000
# Epoch 36/200
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0113 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0028 - val_sparse_categorical_accuracy: 1.0000
# Epoch 37/200
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0063 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0017 - val_sparse_categorical_accuracy: 1.0000
# Epoch 38/200
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0114 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0013 - val_sparse_categorical_accuracy: 1.0000
# Epoch 39/200
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0127 - sparse_categorical_accuracy: 0.9907 - val_loss: 8.8504e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 40/200
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0047 - sparse_categorical_accuracy: 1.0000 - val_loss: 6.8497e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 41/200
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0233 - sparse_categorical_accuracy: 0.9907 - val_loss: 8.1791e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 42/200
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0111 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0020 - val_sparse_categorical_accuracy: 1.0000
# Epoch 43/200
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0057 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0054 - val_sparse_categorical_accuracy: 1.0000
# Epoch 44/200
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0063 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0096 - val_sparse_categorical_accuracy: 1.0000
# Epoch 45/200
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0064 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0115 - val_sparse_categorical_accuracy: 1.0000
# Epoch 46/200
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0116 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0076 - val_sparse_categorical_accuracy: 1.0000
# Epoch 47/200
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0084 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0037 - val_sparse_categorical_accuracy: 1.0000
# Epoch 48/200
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0059 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0021 - val_sparse_categorical_accuracy: 1.0000
# Epoch 49/200
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0069 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0012 - val_sparse_categorical_accuracy: 1.0000
# Epoch 50/200
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0146 - sparse_categorical_accuracy: 1.0000 - val_loss: 6.3710e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 51/200
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0036 - sparse_categorical_accuracy: 1.0000 - val_loss: 3.9708e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 52/200
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0084 - sparse_categorical_accuracy: 1.0000 - val_loss: 3.2216e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 53/200
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0081 - sparse_categorical_accuracy: 1.0000 - val_loss: 2.9330e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 54/200
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0053 - sparse_categorical_accuracy: 1.0000 - val_loss: 2.8609e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 55/200
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0019 - sparse_categorical_accuracy: 1.0000 - val_loss: 2.8867e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 56/200
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0053 - sparse_categorical_accuracy: 1.0000 - val_loss: 2.9543e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 57/200
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0038 - sparse_categorical_accuracy: 1.0000 - val_loss: 3.1615e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 58/200
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0034 - sparse_categorical_accuracy: 1.0000 - val_loss: 3.7228e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 59/200
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0025 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.7769e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 60/200
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0028 - sparse_categorical_accuracy: 1.0000 - val_loss: 6.0910e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 61/200
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0025 - sparse_categorical_accuracy: 1.0000 - val_loss: 7.2856e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 62/200
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0031 - sparse_categorical_accuracy: 1.0000 - val_loss: 7.8437e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 63/200
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0019 - sparse_categorical_accuracy: 1.0000 - val_loss: 8.5792e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 64/200
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0012 - sparse_categorical_accuracy: 1.0000 - val_loss: 9.1798e-04 - val_sparse_categorical_accuracy: 1.0000

# %%
classifier.evaluate(te_feat, y_test)
# Out:
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0705 - sparse_categorical_accuracy: 0.9667
# [0.07047930359840393, 0.9666666388511658]

# %% [markdown]
# #### Visualization

# %%
x_train = np.squeeze(x_train)
y_train = np.squeeze(y_train)
n_class = len(np.unique(y_train))
c = list(mcolors.BASE_COLORS.keys())
embed = TSNE(n_components=2, learning_rate=10, init = 'random', perplexity=10, n_iter=2000).fit_transform(proj_te)
# # pt.scatter(embed[:, 0], embed[:, 1], c=y_test)
for i in range(n_class):
    lab = y_test== i
    pt.scatter(embed[lab, 0], embed[lab, 1], color=c[i])

# %% [markdown]
# #### USC-HAD data Example

# %%
x = np.load('data/USC-HAD/usc_x_train.npy')

# %%
pt.plot(x[0], label='non-change')
pt.plot(x[150], label='change')
pt.legend()

# %% [markdown]
# #### ECochG data Example

# %%
x = np.load('data/ECochG/cm_tr_x.npy')

# %%
pt.plot(x[4081], label='non-change')
pt.plot(x[1999], label='change')
pt.legend()
